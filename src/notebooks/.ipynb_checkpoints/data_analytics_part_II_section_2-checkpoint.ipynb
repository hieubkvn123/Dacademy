# %% [markdown]
# # Machine learning 2 - Classification

# %% [markdown]
# # Import libraries

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.svm import SVC
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import StratifiedShuffleSplit, cross_val_score
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

### For classification visualization purpose ###
from sklearn.datasets import make_classification
from scipy.spatial.distance import cdist
from utils import visualize_svm_model, visualize_knn_model, create_normal_samples

### Import machine learning algorithms ###
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

plt.style.use('ggplot') # change plot style

# %% [markdown]
# # Classification algorithms

# %% [markdown]
# ## 1. K-Nearest Neighbors (KNN)
# * KNN is a simple classification model that makes it prediction merely on the class of the majority of observations near it.

# %% [markdown]
# ### 1.1. Create dataset
# * Suppose we have the following observations (training dataset) of two different classes and we want to classify a new unobserved datapoint.
# * K-nearest neighbor algorithm will start scanning the neighborhood of the new datapoint to look for k nearest neighbors. The class of the new datapoint will be decided based on the majority of the class of the neighbors

# %%
X, Y = create_normal_samples(mean_2=3.0)

fig, ax = plt.subplots(figsize=(7, 7))
colors = ['blue', 'red']
for i, class_ in enumerate(np.unique(Y)):
    cluster = X[Y == class_]
    plt.scatter(cluster[:,0], cluster[:, 1], color=colors[i])
    
plt.show()

# %% [markdown]
# ### 1.2. Create KNN model with k = 5
# * Some examples of KNN with k = 5

# %%
visualize_knn_model(X, Y, loc=1.5)
visualize_knn_model(X, Y, loc=3)
visualize_knn_model(X, Y, loc=0)

# %% [markdown]
# ## 2. Support Vector Machine

# %% [markdown]
# ### 2.1. An intuitive example
# * Suppose we want to classify whether a number of children (whose weights are measured) are obese or not. What is the most intuitive way we can think of to solve this problem?
# * One of the simple approach to this problem is to just select threshold that lies between the boundaries of the weights of both classes

# %%
# set up the figure
def visualize_1d(X1, X2, threshold):
    fig = plt.figure(figsize=(15,5))
    ax = fig.add_subplot(111)
    ax.set_xlim(-1,10)
    ax.set_ylim(-1,10)

    # draw lines
    xmin = 0
    xmax = 9
    y = 5
    height = 1
    
    min_value = min(X1+X2)
    max_value = max(X1+X2)
    ranges = max_value - min_value

    plt.hlines(y, xmin, xmax, color='black')
    plt.vlines(xmin, y - height / 2., y + height / 2., color='black')
    plt.vlines(xmax, y - height / 2., y + height / 2., color='black')
    
    # add numbers
    plt.text(xmin - 0.1, y, min_value, horizontalalignment='right')
    plt.text(xmax + 0.1, y, max_value, horizontalalignment='left')
    
    # draw a point on the line
    for x in X1:
        if(x == min_value or x == max_value):continue
        plt.plot((x-min_value)/ranges*9,y, 'bo', ms = 15, mfc = 'b')
        
    for x in X2:
        if(x == min_value or x == max_value):continue
        plt.plot((x-min_value)/ranges*9,y, 'ro', ms = 15, mfc = 'r')
        
    plt.vlines((threshold-min_value)/ranges*9, y - height / 2., y + height / 2., color='red', linestyle='--')

    # add an arrow
    plt.annotate('Threshold?', ((threshold-min_value)/ranges*9,y), xytext = ((threshold-min_value)/ranges*9 - 1, y + 1), 
                 arrowprops=dict(facecolor='black', shrink=0.1), 
                 horizontalalignment='right')

    plt.title('Children weight samples')
    plt.axis('off')
    plt.show()
    
weights1 = [30, 36, 32, 38, 42, 44, 46, 43, 35]
weights2 = [ 60, 61, 62, 65, 67, 69, 70]
visualize_1d(weights1, weights2, 49)

# %% [markdown]
# * The aim of a support vector machine is to find the best threshold that maximizes the margin of the decision boundaries. In the one dimensional case, it seems easy because all we have to do is take the middle point between the boundaries

# %%
weights1 = [30, 36, 32, 38, 42, 44, 46, 43, 35]
weights2 = [ 60, 61, 62, 65, 67, 69, 70]
visualize_1d(weights1, weights2, max(weights1) + (-max(weights1) + min(weights2))/2)

# %% [markdown]
# * How about now ? How do we find the best threshold or decision boundary for this case where data is multi-dimensional ?
# * If only there is a loss function that we can plug into the gradient descent algorithm to find that best threshold eh?

# %%
X, Y = create_normal_samples(mean_2=5.0)

fig, ax = plt.subplots(figsize=(7, 7))
colors = ['blue', 'red']
for i, class_ in enumerate(np.unique(Y)):
    cluster = X[Y == class_]
    plt.scatter(cluster[:,0], cluster[:, 1], color=colors[i])
    
plt.show()

# %% [markdown]
# ### 2.2. General framework for solving SVM with SGD

# %% [markdown]
# * Support vector machine is another simple classifier but affective and widely used in many problems. The objective is find a decision boundary (A linear function, if not considering the kernel trick) that maximize the margin between the two classes.
# * Last time we talked about gradient descent being an algorithm to minimize a judging criteria. So what is the judging criteria for SVM ?
#
# #### Hinge loss
# ![Hinge Loss formula](https://raw.githubusercontent.com/tejasmhos/Linear-SVM-Using-Squared-Hinge-Loss/master/equation.jpeg)
#
# #### Implement gradient descent with hinge loss

# %%
X, Y = create_normal_samples(mean_2=5.0)
visualize_svm_model(X, Y, lr=0.001, iterations=100)

# %% [markdown]
# <img src='./media/svm_visualization.gif'/>

# %% [markdown]
# ## 3. Decision Tree (and Random Forest Classifier)
# * Previously we talked about how decision tree works in regression problems. For classification problem, the exact same procedure is applied. However instead of splitting the dataset based on the Mean Squared Error, we split using other criterias and the most commonly used is called the Gini Impurity
# * The aim of decision tree in classification is to find a best split that **minimizes** the impurity after split
#
# ![DT splitting](https://s3-ap-southeast-1.amazonaws.com/he-public-data/Information%20Gainf53f0c4.png)

# %% [markdown]
# ### Gini impurity formula
# ![Gini impurity](https://static.wixstatic.com/media/02b811_5df05513ffd4487d843bb401dfa5e0cb~mv2.png/v1/fit/w_309%2Ch_118%2Cal_c%2Cq_80/file.jpg)
# * Gini impurity is a measure that gauges how "pure" a data sample is. The p_{i} is the ratio (ranging from 0 to 1) of data samples that belongs to class C_{i}

# %%
X1, Y1 = create_normal_samples(mean_2=1.0)
X2, Y2 = create_normal_samples(mean_2=1.0)
Y2[:int(len(Y2)*0.95)] = 1
Y1[:int(len(Y2)*0.5)] = 1

def gini(Y):
    gini_id = 1
    
    for C in np.unique(Y):
        p = len(Y[Y == C]) / len(Y)
        gini_id -= p ** 2
        
    return gini_id

fig, ax = plt.subplots(1, 2, figsize=(15, 8))
for i, class_ in enumerate(np.unique(Y1)):
    cluster = X1[Y1 == class_]
    ax[0].scatter(cluster[:,0], cluster[:, 1], color=colors[i])
ax[0].set_title(f'Gini impurity = {gini(Y1):.4f}')
    
for i, class_ in enumerate(np.unique(Y2)):
    cluster = X2[Y2== class_]
    ax[1].scatter(cluster[:,0], cluster[:, 1], color=colors[i])
ax[1].set_title(f'Gini impurity = {gini(Y2):.4f}')
    
plt.show()

# %% [markdown]
# ## 4. Other algorithms to look at (for your self learning purpose)

# %% [markdown]
# ### a. Naive Bayes

# %% [markdown]
# ![Naive Bayes formula](https://www.kdnuggets.com/wp-content/uploads/bayes-nagesh-1.jpg)

# %% [markdown]
# ### b.Logistic Regression

# %% [markdown]
# ![Logistic regression](https://static.javatpoint.com/tutorial/machine-learning/images/logistic-regression-in-machine-learning.png)
